# %%
import pandas as pd

# %%
data = pd.read_csv('outputs/processed_sea_results_with_uniprot_data.csv')

# %%
groupedData = data.groupby(by='Target ID')['Query ID'].count().sort_values()

groupedData.sum()
# Out:
# np.int64(236629)
